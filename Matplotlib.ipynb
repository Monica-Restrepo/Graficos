# %% [markdown]
# <a href="https://colab.research.google.com/github/Monica-Restrepo/Graficos/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En este cuaderno voy a parcticar la creación de gráficos con Matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Los gráficos en matplotlib residen dentro de un objeto Figure.
# fig = plt.figure()

# %%
fig = plt.figure(figsize=(8,6))

# %% [markdown]
# Método plot

# %%
x = ['invierno', 'primavera', 'verano', 'otoño']
y = ['diciembre', 'abril', 'junio', 'septiembre']
plt.plot(x,y)
plt.show()

# %% [markdown]
# Gráficos de líneas  (Line charts)
#  Ideal para representar datos secuenciales y temporales.
#  Permite visualizar el comportamiento de los datos a lo largo del tiempo.

# %%
plt.plot([2,5,6,9,10])
plt.show()

# %%
plt.plot([10,15,31,40],[5,11,13,19])
plt.show()

# %%
plt.plot([10,15,31,40],[5,11,13,19])
plt.axis([4,30,-1,30]) # [xmin,xmax,ymin,ymax]
plt.show()

# %%
ventas = [300,400,500,600,700,600,800]
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio']
plt.plot(meses,ventas)
plt.show()

# %%
ventas_producto1 = [300,400,500,600,700,600,800]
ventas_producto2 = [350,400,550,650,750,650,850]
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio']
plt.plot(meses,ventas_producto1, label='producto 1', color='green')
plt.plot(meses,ventas_producto2, label='producto 2', color='yellow')
plt.show()

# %% [markdown]
# Personalizar gráficos

# %%
ventas = [300,500,500,600,700,600,800]
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio']

plt.plot(meses,ventas, color='pink')
plt.title('Ventas Mensuales')
plt.xlabel('Meses')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# plt.legend() se muestra el nombre de cada linea.
# plt.grid() muestra el grafico con una cuadricula de fondo

# %%
ventas_producto1 = [300,400,500,600,700,600,800]
ventas_producto2 = [350,400,550,650,750,650,850]
meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio']
plt.plot(meses,ventas_producto1, label='producto 1', color='purple')
plt.plot(meses,ventas_producto2, label='producto 2', color='red')
plt.title('Ventas Mensuales')
plt.xlabel('Meses')
plt.ylabel('Ventas')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# propiedades dentro de plt.plot
# color de la linea, linestyle= estilo de la linea, linewidth= grosor de la linea, marker= marcador en cada punto, markesize= tamaño del marcador, markeredgecolor=color del borde del marcador, markerfacecolor = color interno del marcador

# %%
ventas = [300,400,500,600,700,600,800]

meses = ['Enero','Febrero','Marzo','Abril','Mayo','Junio','Julio']
plt.plot(meses,ventas,
         label='producto',
         color='purple',
         linestyle='--',
         linewidth=2,
         marker='o',
         markersize=10,
         markeredgecolor='red',
         markerfacecolor='pink')

plt.xlabel('Meses')
plt.ylabel('Ventas')
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np

# %% [markdown]
# Gráficos de dispersión (Scatter plots) =  Ideal para representar la relación entre dos variables.
# Ejemplo: relación entre altura y peso

# %%
altura = np.random.randint(170,200, size=50)
peso = np.random.randint(60,200, size=50)
plt.scatter(altura,peso, color='red')
plt.title('Relación entre altura y peso')
plt.xlabel('Altura')
plt.ylabel('Peso')
plt.show()

# %%
from numpy.random import rand
x, y = rand(2,100)
x2, y2 = rand(2,100)
plt.scatter(x,y, color='red')
plt.scatter(x2,y2, color='green')
plt.title('Relación entre presio y cantidad vendida')
plt.xlabel('Precio')
plt.ylabel('Cantidad vendida')
plt.show()

# %% [markdown]
# Propiedades de plt.scatter: s = tamaño de los puntos, c = color de los puntos, marker = forma del marcador, alpha = transparencia de 0 a 1, edgecolors = color del borde del punto, linewidths = ancho del borde del punto, label = etiqueta para la leyenda

# %%
x = np.array([5,7,8,7,2])
y = np.array([99,86,87,88,111,])
colores = ['red','green','blue','yellow','pink']
tamaños = [10,20,30,40,50]
plt.scatter(x,y,
            c=colores,
            s=tamaños,
            marker='o',
            alpha=1,
            edgecolors='black',
            linewidths=1.4,
            label='Clientes potenciales')
plt.title('Distribución de clientes')
plt.xlabel('Pais')
plt.ylabel('Costo compra')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Gráficos de barras (Bar Charts): Ideal para representar datos
#  categóricos y/o comparaciones entre categorías.

# %%
productos = ['prod1', 'prod2', 'prod3', 'prod4']
ventas = [300,400,500,600]
plt.bar(productos,ventas, color='skyblue')
plt.title('Ventas productos')
plt.xlabel('Productos')
plt.ylabel('Ventas')
plt.show()

# %%
productos = ['prod1', 'prod2', 'prod3', 'prod4']
ventas = [300,400,500,600]
plt.barh(productos,ventas, color='lightcoral')
plt.title('Ventas productos')
plt.xlabel('Productos')
plt.ylabel('Ventas')
plt.show()

# %% [markdown]
# Barras verticales apiladas
#
# bottom = especifica dónde
#  empieza cada barra en el eje
#  Y o en el eje X (para gráficos
#  de barras horizontales). Ya
#  que por defecto, las barras
#  comienzan desde cero.

# %%
trimestre_año = ['trimestre 1', 'trimestre 2', 'trimestre 3', 'trimestre 4']
ventas_producto1 = [300,400,500,600]
ventas_producto2 = [350,400,550,650]

plt.bar(trimestre_año, ventas_producto1,  bottom=ventas_producto2, label='Producto1', color= 'lightblue')
plt.bar(trimestre_año, ventas_producto2, label='Producto2', color= 'lightgreen')

plt.title('Ventas por trimestre peoducto 1 y 2')
plt.xlabel('Productos')
plt.ylabel('Ventas')
plt.legend()
plt.show()

# %% [markdown]
# Propiedades de plt.bar: color = color de las barras, edgecolor= color del borde de las barras, linewidth = ancho del borde de las barras, width = ancho de las barras, label = nombre para usar la leyenda, bottom = posición base de las barras
#
# plt.tight_layout(): Evita que las etiquetas de los ejes se corten.
#
# Ajusta los espacios entre el título, los ejes, la leyenda y las barras.
#
# Hace que el gráfico se vea más limpio y mejor distribuido dentro del área de dibujo.

# %%
categorias = ['A', 'B', 'C', 'D']
ventas = [10,20,30,40]

plt.bar(categorias,
        ventas,
        color='lightgreen',
        edgecolor='black',
        linewidth=1.5,
        width=0.6,
        label='Ventas 2025')
plt.title('Ventas por categoria')
plt.xlabel('Categorias')
plt.ylabel('Ventas')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Histogramas:  Ideal para representar datos continuos.
# Permite mostrar la distribución de una variable.
#
# np.random.randint, que es otra forma de generar números aleatorios, pero esta vez con números enteros, no continuos como en np.random.normal.

# %%
# Generar datos aleatorios
edades = np.random.randint(15,90, size=100)

plt.hist(edades, bins=10, color='skyblue', edgecolor='green')
plt.title('Distribución de edades clientes')
plt.xlabel('Edades')
plt.ylabel('Numero de clientes')
plt.show()

# %% [markdown]
# Propiedades de plt.hist: bins = numero de divisiones o contenedores del histograma, color = color de las barras, edgecolor = color borde de las barras, alpha = transparencia de las barras de 0 a 1, label = etiqueta para incluir la leyenda, histtype = tipo de histograma (bar, step, stepfilled), orientation = vertical, horizontal, rwidth =  ancho relativo de las barras de 0 a 1, 1 por defecto.
#
# np.random.normal =  estás generando números aleatorios que siguen una distribución normal (también llamada distribución gaussiana o campana de Gauss)
#
# loc: es la media (el valor central de la distribución).
#
# scale: es la desviación estándar (qué tan dispersos están los datos).
#
# size: es cuántos valores quieres generar.
#
# Es útil para:
#
# Simular datos cuando no tienes los reales.
#
# Crear distribuciones de prueba.
#
# Evaluar comportamientos típicos de un fenómeno (como ventas promedio, temperaturas, etc.)

# %%
data = np.random.normal(loc=50, scale=10, size=100)
plt.hist(data,
         bins=20,
         color='lightcoral',
         edgecolor='red',
         alpha=0.6,
         rwidth=0.9,
         label='Distribución de edades',
         histtype='bar')
plt.title('Distribución de edades clientes')
plt.xlabel('Edades')
plt.ylabel('Numero de clientes')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
data = np.random.normal(loc=50, scale=10, size=100)
plt.hist(data,
         bins=20,
         color='green',
         edgecolor='green',
         alpha=0.6,
         rwidth=0.9,
         label='Distribución de edades',
         histtype='step')
plt.title('Distribución de edades clientes')
plt.xlabel('Edades')
plt.ylabel('Numero de clientes')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
data = np.random.normal(loc=50, scale=10, size=100)
plt.hist(data,
         bins=20,
         color='lightblue',
         edgecolor='blue',
         alpha=0.6,
         rwidth=0.9,
         label='Distribución de edades',
         histtype='stepfilled')
plt.title('Distribución de edades clientes')
plt.xlabel('Edades')
plt.ylabel('Numero de clientes')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# Gráficos de pastel: Ideal para representar proporciones de un todo.
# Usualmente útil para datos categóricos
#
# propiedades: labels = lista de nombre para cada porción, colors = lista de colores personalizados, autopct = muestra los valores porcentuales o personalizados de cada porción, startangle = ángulo inicial del gráfico en grados (gira el pastel), explode = separa porciones para destacarlas, shadow = agrega una sombra al grafico, radius = bradio del pastel, por defecto es 1, counterclock = dirección de las porciones, por defecto antihorario, pctdistance =  distancia del texto del porcentaje dede el centro, labeldistance = distancia del texto de etiquetas desde el centro.

# %%
productos = ['prod1', 'prod2', 'prod3', 'prod4']
ventas = [300,400,500,600]

plt.pie(ventas, labels=productos, autopct='%1.1f%%', startangle=90)
plt.title('Proporción de ventas por producto')
plt.show()

# %%
valores = [30, 45, 25]
etiquetas = ['ventas','Marketing','producción']
colores = ['gold','lightcoral','lightskyblue']
explode = (0.1, 0.1, 0)

plt.pie(valores,
        labels=etiquetas,
        colors=colores,
        explode=explode,
        autopct='%1.1f%%',
        shadow=True,
        startangle=80,
        counterclock=False)
plt.title('Distribución de presupuesto anual')
plt.tight_layout()
plt.show()

# %% [markdown]
#  Subgráficos
